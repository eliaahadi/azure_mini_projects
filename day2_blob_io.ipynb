# %%
import os
from dotenv import load_dotenv

import pandas as pd
from azure.storage.blob import BlobServiceClient

load_dotenv()

CONNECTION_STRING = os.getenv("AZURE_STORAGE_CONNECTION_STRING")
CONTAINER_NAME = os.getenv("AZURE_STORAGE_CONTAINER", "ml-data")

if not CONNECTION_STRING:
    raise ValueError("AZURE_STORAGE_CONNECTION_STRING not set in environment")

print("Using container:", CONTAINER_NAME)
# Out:
# Using container: ml-data

# %%
blob_service_client = BlobServiceClient.from_connection_string(CONNECTION_STRING)

container_client = blob_service_client.get_container_client(CONTAINER_NAME)

# Ensure the container exists (create if missing)
try:
    if not container_client.exists():
        container_client.create_container()
        print(f"Created container: {CONTAINER_NAME}")
    else:
        print(f"Container already exists: {CONTAINER_NAME}")
except Exception as e:
    print("Failed to check/create container:", e)
    raise
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 blob_service_client = BlobServiceClient.from_connection_string(CONNECTION_STRING)
#       3 container_client = blob_service_client.get_container_client(CONTAINER_NAME)
#       5 # Ensure the container exists (create if missing)
#
# File /opt/anaconda3/lib/python3.13/site-packages/azure/storage/blob/_blob_service_client.py:221, in BlobServiceClient.from_connection_string(cls, conn_str, credential, **kwargs)
#     161 @classmethod
#     162 def from_connection_string(
#     163     cls, conn_str: str,
#     164     credential: Optional[Union[str, Dict[str, str], "AzureNamedKeyCredential", "AzureSasCredential", "TokenCredential"]] = None,  # pylint: disable=line-too-long
#     165     **kwargs: Any
#     166 ) -> Self:
#     167     """Create BlobServiceClient from a Connection String.
#     168
#     169     :param str conn_str:
#    (...)
#     219             :caption: Creating the BlobServiceClient from a connection string.
#     220     """
# --> 221     account_url, secondary, credential = parse_connection_str(conn_str, credential, 'blob')
#     222     if 'secondary_hostname' not in kwargs:
#     223         kwargs['secondary_hostname'] = secondary
#
# File /opt/anaconda3/lib/python3.13/site-packages/azure/storage/blob/_shared/base_client.py:408, in parse_connection_str(conn_str, credential, service)
#     406 conn_settings_list = [s.split("=", 1) for s in conn_str.split(";")]
#     407 if any(len(tup) != 2 for tup in conn_settings_list):
# --> 408     raise ValueError("Connection string is either blank or malformed.")
#     409 conn_settings = dict((key.upper(), val) for key, val in conn_settings_list)
#     410 endpoints = _SERVICE_PARAMS[service]
#
# ValueError: Connection string is either blank or malformed.

# %% [markdown]
# Day 2

# %%
from sklearn.datasets import load_breast_cancer

data = load_breast_cancer(as_frame=True)
df = data.frame

local_csv_path = "day1_breast_cancer.csv"
df.to_csv(local_csv_path, index=False)
local_csv_path

# %%
blob_name = "raw/day1_breast_cancer.csv"  # folder-like path in container

blob_client = container_client.get_blob_client(blob_name)

with open(local_csv_path, "rb") as f:
    blob_client.upload_blob(f, overwrite=True)

print(f"Uploaded {local_csv_path} to blob '{blob_name}'")

# %%
print("Blobs in container:")
for blob in container_client.list_blobs():
    print("-", blob.name)

# %%
download_path = "downloaded_day1_breast_cancer.csv"

with open(download_path, "wb") as f:
    download_stream = blob_client.download_blob()
    f.write(download_stream.readall())

print(f"Downloaded blob to {download_path}")

df_downloaded = pd.read_csv(download_path)
df_downloaded.head()
